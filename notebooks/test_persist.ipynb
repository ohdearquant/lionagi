# %%
from lionagi import create_message

a = create_message(
    instruction="hello world",
)

# %%
a.to_dict(mode="db")
# Out:
# {'id': '551b2943-9419-400f-9c3e-19afda297122',
#  'created_at': 1779292845.913595,
#  'content': {'images': [],
#   'tool_schemas': [],
#   'prompt_context': [],
#   'instruction': 'hello world'},
#  'embedding': None,
#  'sender': None,
#  'recipient': None,
#  'channel': None,
#  'role': 'user',
#  'node_metadata': {'lion_class': 'lionagi.protocols.messages.instruction.Instruction'}}

# %%
from lionagi import Branch

Branch().to_dict(mode="db")
# Out:
# {'id': '1f1cf287-32e9-40ce-9b8e-e9086a456bea',
#  'created_at': 1779292845.966259,
#  'user': None,
#  'name': None,
#  'node_metadata': {'lion_class': 'lionagi.session.branch.Branch'},
#  'chat_model': {'id': 'fa0b6f51-efe3-4a98-a1f8-91a845203a55',
#   'created_at': 1779292845.966338,
#   'provider_metadata': {},
#   'endpoint': {'retry_config': None,
#    'circuit_breaker': None,
#    'config': {'name': 'openai_chat/completions',
#     'provider': 'openai',
#     'base_url': 'https://api.openai.com/v1',
#     'endpoint': 'chat/completions',
#     'method': 'POST',
#     'params': {},
#     'content_type': 'application/json',
#     'auth_type': 'bearer',
#     'default_headers': {},
#     'timeout': 600,
#     'max_retries': 3,
#     'openai_compatible': False,
#     'requires_tokens': True,
#     'kwargs': {'model': 'gpt-4.1-mini'},
#     'client_kwargs': {}}}}}

# %%
a.to_dict()
# Out:
# {'ln_id': '16c86ba852eca06dac215d13ef63c204',
#  'created': '2026-05-20T15:11:33.758267',
#  'metadata': {},
#  'content': {'foo': 'bar'},
#  'embedding': [],
#  'relations': {'in': {'ln_id': '7af961ecfc54dc589495fc0075022424',
#    'created': '2026-05-20T15:11:33.758461',
#    'use_obj': False,
#    'pile': {},
#    'item_type': None,
#    'name': None,
#    'order': [],
#    'index': None,
#    'engines': {},
#    'query_response': [],
#    'tools': {}},
#   'out': {'ln_id': '5584fa1a592fa88e5c92aabedd305898',
#    'created': '2026-05-20T15:11:33.758659',
#    'use_obj': False,
#    'pile': {},
#    'item_type': None,
#    'name': None,
#    'order': [],
#    'index': None,
#    'engines': {},
#    'query_response': [],
#    'tools': {}}},
#  'lion_class': 'Node'}
